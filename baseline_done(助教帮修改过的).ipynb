# %% [markdown]
# # 导入工具包

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # 读取数据

# %%
dir_path = '../input/google-smartphone-decimeter-challenge'

# %%
file_train = os.path.join(dir_path, "baseline_locations_train.csv")
file_test = os.path.join(dir_path, "baseline_locations_test.csv")
file_sub = os.path.join(dir_path, "sample_submission.csv")

# %%
file_train
# Out:
# '../input/google-smartphone-decimeter-challenge/baseline_locations_train.csv'

# %%
data_train = pd.read_csv(file_train)
data_test = pd.read_csv(file_test)
data_sub = pd.read_csv(file_sub)

# %%
data_train.head(3)
# Out:
#         collectionName phoneName  millisSinceGpsEpoch     latDeg      lngDeg  \
# 0  2020-05-14-US-MTV-1    Pixel4        1273529463442  37.423575 -122.094091
# 1  2020-05-14-US-MTV-1    Pixel4        1273529464442  37.423578 -122.094101
# 2  2020-05-14-US-MTV-1    Pixel4        1273529465442  37.423573 -122.094111
#
#    heightAboveWgs84EllipsoidM                       phone
# 0                      -34.06  2020-05-14-US-MTV-1_Pixel4
# 1                      -33.29  2020-05-14-US-MTV-1_Pixel4
# 2                      -30.99  2020-05-14-US-MTV-1_Pixel4

# %%
path_data = Path(dir_path)
path_truth_data = (path_data/'train').rglob('ground_truth.csv')

# %%
path_data
# Out:
# PosixPath('../input/google-smartphone-decimeter-challenge')

# %%
# list(path_truth_data)

# %%
data_truth_list =[]
for file_name in tqdm(path_truth_data, total=73):
    data_file = pd.read_csv(file_name)
    data_truth_list.append(data_file)
# Out:
# 100%|██████████| 73/73 [00:01<00:00, 55.63it/s]

# %%
# data_truth_list[:1]

# %%
data_train_truth = pd.concat(data_truth_list, ignore_index=True)

# %%
data_train_truth.head(3)
# Out:
#         collectionName phoneName  millisSinceGpsEpoch     latDeg      lngDeg  \
# 0  2020-07-17-US-MTV-1       Mi8        1279059935000  37.428281 -122.072541
# 1  2020-07-17-US-MTV-1       Mi8        1279059936000  37.428281 -122.072541
# 2  2020-07-17-US-MTV-1       Mi8        1279059937000  37.428281 -122.072541
#
#    heightAboveWgs84EllipsoidM  timeSinceFirstFixSeconds  hDop  vDop  speedMps  \
# 0                       34.71                     669.0   0.8   0.0       0.0
# 1                       34.71                     670.0   0.8   0.0       0.0
# 2                       34.71                     671.0   0.8   0.0       0.0
#
#    courseDegree
# 0         242.8
# 1         242.8
# 2         242.8

# %%
len(data_train), len(data_test), len(data_train_truth)
# Out:
# (131342, 91486, 131342)

# %%
data_train_truth.columns
# Out:
# Index(['collectionName', 'phoneName', 'millisSinceGpsEpoch', 'latDeg',
#        'lngDeg', 'heightAboveWgs84EllipsoidM', 'timeSinceFirstFixSeconds',
#        'hDop', 'vDop', 'speedMps', 'courseDegree'],
#       dtype='object')

# %%
set(data_train_truth.columns) & set(data_train.columns)
# Out:
# {'collectionName',
#  'heightAboveWgs84EllipsoidM',
#  'latDeg',
#  'lngDeg',
#  'millisSinceGpsEpoch',
#  'phoneName'}

# %% [markdown]
# # 合并数据

# %%
train_columns = ['collectionName', 'phoneName', 'millisSinceGpsEpoch','latDeg','lngDeg']
merge_columns = ['collectionName', 'phoneName', 'millisSinceGpsEpoch']
pd_train = data_train_truth[train_columns].merge(data_train,
                       on=merge_columns,
                      suffixes=("_truth",""))

# %%
pd_test = data_test

# %%
# del pd_train['phone']
# del pd_test['phone']

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
pd_train.head(3)
# Out:
#         collectionName phoneName  millisSinceGpsEpoch  latDeg_truth  \
# 0  2020-07-17-US-MTV-1       Mi8        1279059935000     37.428281
# 1  2020-07-17-US-MTV-1       Mi8        1279059936000     37.428281
# 2  2020-07-17-US-MTV-1       Mi8        1279059937000     37.428281
#
#    lngDeg_truth     latDeg      lngDeg  heightAboveWgs84EllipsoidM  \
# 0   -122.072541  37.428288 -122.072583                      -16.14
# 1   -122.072541  37.428271 -122.072521                      -24.96
# 2   -122.072541  37.428234 -122.072572                      -24.38
#
#                      phone
# 0  2020-07-17-US-MTV-1_Mi8
# 1  2020-07-17-US-MTV-1_Mi8
# 2  2020-07-17-US-MTV-1_Mi8

# %%
# 手机，t1, 1
# 手机，t2, 2
# 手机，t3, 3



# 手机，t1, nan
# 手机，t2, 1
# 手机，t3, 2

# %% [markdown]
# # 按时间排序

# %%
pd_train = pd_train.sort_values(['collectionName', 'phoneName', 'millisSinceGpsEpoch'])

# %%
pd_test = pd_test.sort_values(['collectionName', 'phoneName', 'millisSinceGpsEpoch'])

# %%
len(pd_train.drop_duplicates(['collectionName','phoneName','latDeg_truth','lngDeg_truth']))
# Out:
# 118624

# %%
len(pd_train.drop_duplicates(['collectionName','latDeg_truth','lngDeg_truth']))
# Out:
# 118624

# %%
len(pd_train)
# Out:
# 131342

# %%
len(set(pd_train['millisSinceGpsEpoch']))
# Out:
# 128295

# %%
len(set(pd_train['phoneName']))
# Out:
# 7

# %%
len(set(pd_train['collectionName']))
# Out:
# 29

# %%
len(pd_test)
# Out:
# 91486

# %% [markdown]
# # 特征工程

# %%
pd_test.columns
# Out:
# Index(['collectionName', 'phoneName', 'millisSinceGpsEpoch', 'latDeg',
#        'lngDeg', 'heightAboveWgs84EllipsoidM', 'phone'],
#       dtype='object')

# %%
pd_train.head(3)
# Out:
#            collectionName phoneName  millisSinceGpsEpoch  latDeg_truth  \
# 9124  2020-05-14-US-MTV-1    Pixel4        1273529463442     37.423576
# 9125  2020-05-14-US-MTV-1    Pixel4        1273529464442     37.423576
# 9126  2020-05-14-US-MTV-1    Pixel4        1273529465442     37.423576
#
#       lngDeg_truth     latDeg      lngDeg  heightAboveWgs84EllipsoidM  \
# 9124   -122.094132  37.423575 -122.094091                      -34.06
# 9125   -122.094132  37.423578 -122.094101                      -33.29
# 9126   -122.094132  37.423573 -122.094111                      -30.99
#
#                            phone
# 9124  2020-05-14-US-MTV-1_Pixel4
# 9125  2020-05-14-US-MTV-1_Pixel4
# 9126  2020-05-14-US-MTV-1_Pixel4

# %%
pd_test.head(3)
# Out:
#         collectionName phoneName  millisSinceGpsEpoch     latDeg      lngDeg  \
# 0  2020-05-15-US-MTV-1    Pixel4        1273608785432  37.416628 -122.082053
# 1  2020-05-15-US-MTV-1    Pixel4        1273608786432  37.416646 -122.082040
# 2  2020-05-15-US-MTV-1    Pixel4        1273608787432  37.416652 -122.082039
#
#    heightAboveWgs84EllipsoidM                       phone
# 0                      -30.69  2020-05-15-US-MTV-1_Pixel4
# 1                      -31.76  2020-05-15-US-MTV-1_Pixel4
# 2                      -31.65  2020-05-15-US-MTV-1_Pixel4

# %% [markdown]
# ## 类别特征

# %%
set(pd_test['collectionName'])
# Out:
# {'2020-05-15-US-MTV-1',
#  '2020-05-28-US-MTV-1',
#  '2020-05-28-US-MTV-2',
#  '2020-06-04-US-MTV-2',
#  '2020-06-10-US-MTV-1',
#  '2020-06-10-US-MTV-2',
#  '2020-08-03-US-MTV-2',
#  '2020-08-13-US-MTV-1',
#  '2021-03-16-US-MTV-2',
#  '2021-03-16-US-RWC-2',
#  '2021-03-25-US-PAO-1',
#  '2021-04-02-US-SJC-1',
#  '2021-04-08-US-MTV-1',
#  '2021-04-21-US-MTV-1',
#  '2021-04-22-US-SJC-2',
#  '2021-04-26-US-SVL-2',
#  '2021-04-28-US-MTV-2',
#  '2021-04-29-US-MTV-2',
#  '2021-04-29-US-SJC-3'}

# %%
dict_ = dict(zip(set(pd_test['collectionName']), range(len(set(pd_test['collectionName'])))))
pd_train['collectionName_cat01'] = pd_train['collectionName'].map(dict_)
pd_test['collectionName_cat01'] = pd_test['collectionName'].map(dict_)

# %%
dict_
# Out:
# {'2021-04-21-US-MTV-1': 0,
#  '2020-08-13-US-MTV-1': 1,
#  '2020-05-28-US-MTV-1': 2,
#  '2020-06-10-US-MTV-1': 3,
#  '2021-04-26-US-SVL-2': 4,
#  '2021-03-25-US-PAO-1': 5,
#  '2020-06-10-US-MTV-2': 6,
#  '2021-03-16-US-RWC-2': 7,
#  '2021-04-28-US-MTV-2': 8,
#  '2020-08-03-US-MTV-2': 9,
#  '2021-04-02-US-SJC-1': 10,
#  '2020-05-15-US-MTV-1': 11,
#  '2021-04-08-US-MTV-1': 12,
#  '2021-03-16-US-MTV-2': 13,
#  '2021-04-22-US-SJC-2': 14,
#  '2020-05-28-US-MTV-2': 15,
#  '2021-04-29-US-MTV-2': 16,
#  '2020-06-04-US-MTV-2': 17,
#  '2021-04-29-US-SJC-3': 18}

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
set(pd_test['phoneName'])
# Out:
# {'Mi8',
#  'Pixel4',
#  'Pixel4Modded',
#  'Pixel4XL',
#  'Pixel4XLModded',
#  'Pixel5',
#  'SamsungS20Ultra'}

# %%
# len(list('SamsungS20Ultra'))

# %%
dict_ = dict(zip(set(pd_test['phoneName']), range(len(set(pd_test['phoneName'])))))
pd_train['phoneName_cat01'] = pd_train['phoneName'].map(dict_)
pd_test['phoneName_cat01'] = pd_test['phoneName'].map(dict_)

# %%
dict_
# Out:
# {'Pixel4Modded': 0,
#  'Mi8': 1,
#  'SamsungS20Ultra': 2,
#  'Pixel5': 3,
#  'Pixel4': 4,
#  'Pixel4XLModded': 5,
#  'Pixel4XL': 6}

# %%
pd_test
# Out:
#             collectionName        phoneName  millisSinceGpsEpoch     latDeg  \
# 0      2020-05-15-US-MTV-1           Pixel4        1273608785432  37.416628
# 1      2020-05-15-US-MTV-1           Pixel4        1273608786432  37.416646
# 2      2020-05-15-US-MTV-1           Pixel4        1273608787432  37.416652
# 3      2020-05-15-US-MTV-1           Pixel4        1273608788432  37.416607
# 4      2020-05-15-US-MTV-1           Pixel4        1273608789432  37.416609
# ...                    ...              ...                  ...        ...
# 91481  2021-04-29-US-SJC-3  SamsungS20Ultra        1303763185000  37.334539
# 91482  2021-04-29-US-SJC-3  SamsungS20Ultra        1303763186000  37.334545
# 91483  2021-04-29-US-SJC-3  SamsungS20Ultra        1303763187000  37.334551
# 91484  2021-04-29-US-SJC-3  SamsungS20Ultra        1303763188000  37.334540
# 91485  2021-04-29-US-SJC-3  SamsungS20Ultra        1303763189000  37.334562
#
#            lngDeg  heightAboveWgs84EllipsoidM  \
# 0     -122.082053                      -30.69
# 1     -122.082040                      -31.76
# 2     -122.082039                      -31.65
# 3     -122.082063                      -31.52
# 4     -122.082073                      -28.95
# ...           ...                         ...
# 91481 -121.899383                       -8.39
# 91482 -121.899380                       -7.36
# 91483 -121.899371                       -4.08
# 91484 -121.899371                       -5.70
# 91485 -121.899354                       -0.90
#
#                                      phone  collectionName_cat01  \
# 0               2020-05-15-US-MTV-1_Pixel4                    11
# 1               2020-05-15-US-MTV-1_Pixel4                    11
# 2               2020-05-15-US-MTV-1_Pixel4                    11
# 3               2020-05-15-US-MTV-1_Pixel4                    11
# 4               2020-05-15-US-MTV-1_Pixel4                    11
# ...                                    ...                   ...
# 91481  2021-04-29-US-SJC-3_SamsungS20Ultra                    18
# 91482  2021-04-29-US-SJC-3_SamsungS20Ultra                    18
# 91483  2021-04-29-US-SJC-3_SamsungS20Ultra                    18
# 91484  2021-04-29-US-SJC-3_SamsungS20Ultra                    18
# 91485  2021-04-29-US-SJC-3_SamsungS20Ultra                    18
#
#        phoneName_cat01
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    4
# ...                ...
# 91481                2
# 91482                2
# 91483                2
# 91484                2
# 91485                2
#
# [91486 rows x 9 columns]

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %% [markdown]
# ## shift做特征

# %%
shift_list = [-6,-5,-4,-3,-2,-1,1,2,3,4,5,6]
shift_columns = ['millisSinceGpsEpoch','latDeg','lngDeg','heightAboveWgs84EllipsoidM']
for shift_i in shift_list:
    
    tmp_test = pd_test.groupby(['collectionName','phoneName']).shift(shift_i)
    for col in shift_columns:
        pd_test[col+'_shift_'+str(shift_i)] =  tmp_test[col]
        
    tmp_train = pd_train.groupby(['collectionName','phoneName']).shift(shift_i)
    for col in shift_columns:
        pd_train[col+'_shift_'+str(shift_i)] =  tmp_train[col]

# %%
pd_train
# Out:
#             collectionName        phoneName  millisSinceGpsEpoch  \
# 9124   2020-05-14-US-MTV-1           Pixel4        1273529463442
# 9125   2020-05-14-US-MTV-1           Pixel4        1273529464442
# 9126   2020-05-14-US-MTV-1           Pixel4        1273529465442
# 9127   2020-05-14-US-MTV-1           Pixel4        1273529466442
# 9128   2020-05-14-US-MTV-1           Pixel4        1273529467442
# ...                    ...              ...                  ...
# 54337  2021-04-29-US-SJC-2  SamsungS20Ultra        1303760315000
# 54338  2021-04-29-US-SJC-2  SamsungS20Ultra        1303760316000
# 54339  2021-04-29-US-SJC-2  SamsungS20Ultra        1303760317000
# 54340  2021-04-29-US-SJC-2  SamsungS20Ultra        1303760318000
# 54341  2021-04-29-US-SJC-2  SamsungS20Ultra        1303760319000
#
#        latDeg_truth  lngDeg_truth     latDeg      lngDeg  \
# 9124      37.423576   -122.094132  37.423575 -122.094091
# 9125      37.423576   -122.094132  37.423578 -122.094101
# 9126      37.423576   -122.094132  37.423573 -122.094111
# 9127      37.423576   -122.094132  37.423583 -122.094121
# 9128      37.423576   -122.094132  37.423579 -122.094114
# ...             ...           ...        ...         ...
# 54337     37.334475   -121.899613  37.334460 -121.899600
# 54338     37.334475   -121.899613  37.334472 -121.899583
# 54339     37.334475   -121.899613  37.334491 -121.899597
# 54340     37.334475   -121.899613  37.334495 -121.899583
# 54341     37.334475   -121.899613  37.334485 -121.899570
#
#        heightAboveWgs84EllipsoidM                                phone  \
# 9124                       -34.06           2020-05-14-US-MTV-1_Pixel4
# 9125                       -33.29           2020-05-14-US-MTV-1_Pixel4
# 9126                       -30.99           2020-05-14-US-MTV-1_Pixel4
# 9127                       -32.83           2020-05-14-US-MTV-1_Pixel4
# 9128                       -34.49           2020-05-14-US-MTV-1_Pixel4
# ...                           ...                                  ...
# 54337                       -8.09  2021-04-29-US-SJC-2_SamsungS20Ultra
# 54338                       -7.59  2021-04-29-US-SJC-2_SamsungS20Ultra
# 54339                       -8.35  2021-04-29-US-SJC-2_SamsungS20Ultra
# 54340                       -8.73  2021-04-29-US-SJC-2_SamsungS20Ultra
# 54341                       -7.64  2021-04-29-US-SJC-2_SamsungS20Ultra
#
#        collectionName_cat01  ...  lngDeg_shift_4  \
# 9124                    NaN  ...             NaN
# 9125                    NaN  ...             NaN
# 9126                    NaN  ...             NaN
# 9127                    NaN  ...             NaN
# 9128                    NaN  ...     -122.094091
# ...                     ...  ...             ...
# 54337                   NaN  ...     -121.899615
# 54338                   NaN  ...     -121.899603
# 54339                   NaN  ...     -121.899587
# 54340                   NaN  ...     -121.899610
# 54341                   NaN  ...     -121.899600
#
#        heightAboveWgs84EllipsoidM_shift_4  millisSinceGpsEpoch_shift_5  \
# 9124                                  NaN                          NaN
# 9125                                  NaN                          NaN
# 9126                                  NaN                          NaN
# 9127                                  NaN                          NaN
# 9128                               -34.06                          NaN
# ...                                   ...                          ...
# 54337                               -6.06                 1.303760e+12
# 54338                               -7.62                 1.303760e+12
# 54339                               -8.44                 1.303760e+12
# 54340                               -5.91                 1.303760e+12
# 54341                               -8.09                 1.303760e+12
#
#        latDeg_shift_5  lngDeg_shift_5  heightAboveWgs84EllipsoidM_shift_5  \
# 9124              NaN             NaN                                 NaN
# 9125              NaN             NaN                                 NaN
# 9126              NaN             NaN                                 NaN
# 9127              NaN             NaN                                 NaN
# 9128              NaN             NaN                                 NaN
# ...               ...             ...                                 ...
# 54337       37.334488     -121.899626                               -5.10
# 54338       37.334466     -121.899615                               -6.06
# 54339       37.334468     -121.899603                               -7.62
# 54340       37.334468     -121.899587                               -8.44
# 54341       37.334457     -121.899610                               -5.91
#
#        millisSinceGpsEpoch_shift_6  latDeg_shift_6  lngDeg_shift_6  \
# 9124                           NaN             NaN             NaN
# 9125                           NaN             NaN             NaN
# 9126                           NaN             NaN             NaN
# 9127                           NaN             NaN             NaN
# 9128                           NaN             NaN             NaN
# ...                            ...             ...             ...
# 54337                 1.303760e+12       37.334487     -121.899641
# 54338                 1.303760e+12       37.334488     -121.899626
# 54339                 1.303760e+12       37.334466     -121.899615
# 54340                 1.303760e+12       37.334468     -121.899603
# 54341                 1.303760e+12       37.334468     -121.899587
#
#        heightAboveWgs84EllipsoidM_shift_6
# 9124                                  NaN
# 9125                                  NaN
# 9126                                  NaN
# 9127                                  NaN
# 9128                                  NaN
# ...                                   ...
# 54337                              -10.10
# 54338                               -5.10
# 54339                               -6.06
# 54340                               -7.62
# 54341                               -8.44
#
# [131342 rows x 59 columns]

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
len(pd_train.columns), len(pd_test.columns)
# Out:
# (59, 57)

# %% [markdown]
# ## 基本groupby特征

# %%
groupby_columns = ['millisSinceGpsEpoch']
values_columns = ['latDeg','lngDeg','heightAboveWgs84EllipsoidM']
function_names = ['sum','mean','size','min','max']
data_list = [pd_train, pd_test]
data_out = []
for data in data_list:
    tmp = data.\
    groupby(groupby_columns)[values_columns].\
    agg(function_names).\
    reset_index()

    tmp_columns = groupby_columns.copy()
    for i in values_columns:
        for j in function_names:
            tmp_columns.append('_'.join(groupby_columns) + '_' + i + '_' + j )

    tmp.columns = tmp_columns
    
    data = data.merge(tmp,on=groupby_columns)
    data_out.append(data)
pd_train, pd_test = data_out

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
len(pd_train.columns), len(pd_test.columns)
# Out:
# (74, 72)

# %%
groupby_columns = ['collectionName']
values_columns = ['latDeg','lngDeg','heightAboveWgs84EllipsoidM']
function_names = ['sum','mean','size','min','max']
data_list = [pd_train, pd_test]
data_out = []
for data in data_list:
    tmp = data.\
    groupby(groupby_columns)[values_columns].\
    agg(function_names).\
    reset_index()

    tmp_columns = groupby_columns.copy()
    for i in values_columns:
        for j in function_names:
            tmp_columns.append('_'.join(groupby_columns) + '_' + i + '_' + j )

    tmp.columns = tmp_columns
    
    data = data.merge(tmp,on=groupby_columns)
    data_out.append(data)
pd_train, pd_test = data_out

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
len(pd_train.columns), len(pd_test.columns)
# Out:
# (89, 87)

# %%
groupby_columns = ['collectionName','phoneName']
values_columns = ['latDeg','lngDeg','heightAboveWgs84EllipsoidM']
function_names = ['sum','mean','size','min','max']
data_list = [pd_train, pd_test]
data_out = []
for data in data_list:
    tmp = data.\
    groupby(groupby_columns)[values_columns].\
    agg(function_names).\
    reset_index()

    tmp_columns = groupby_columns.copy()
    for i in values_columns:
        for j in function_names:
            tmp_columns.append('_'.join(groupby_columns) + '_' + i + '_' + j )

    tmp.columns = tmp_columns
    
    data = data.merge(tmp,on=groupby_columns)
    data_out.append(data)
pd_train, pd_test = data_out

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
len(pd_train.columns), len(pd_test.columns)
# Out:
# (104, 102)

# %%
groupby_columns = ['phoneName']
values_columns = ['latDeg','lngDeg','heightAboveWgs84EllipsoidM']
function_names = ['sum','mean','size','min','max']
data_list = [pd_train, pd_test]
data_out = []
for data in data_list:
    tmp = data.\
    groupby(groupby_columns)[values_columns].\
    agg(function_names).\
    reset_index()

    tmp_columns = groupby_columns.copy()
    for i in values_columns:
        for j in function_names:
            tmp_columns.append('_'.join(groupby_columns) + '_' + i + '_' + j )

    tmp.columns = tmp_columns
    
    data = data.merge(tmp,on=groupby_columns)
    data_out.append(data)
pd_train, pd_test = data_out

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
len(pd_train.columns), len(pd_test.columns)
# Out:
# (119, 117)

# %% [markdown]
# ## 滑动平均特征

# %%
# df.rolling(3, center=True).mean()
# df.rolling(3, center=True).min()
# df.rolling(3, center=True).max()
# df.rolling(3, center=True).sum()
# DataFrame.rolling(window, min_periods=None, center=False, win_type=None, on=None, axis=0, closed=None)

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
# pd_train

# %%
groupby_columns = ['collectionName','phoneName']
rolling_columns = ['latDeg','lngDeg','heightAboveWgs84EllipsoidM']
window_list = [2,3,5,7,10]
for i in window_list:
    for data in [pd_train, pd_test]:
        temp = data.groupby(groupby_columns)[rolling_columns].\
        rolling(i, center=True).mean().reset_index()
        for col in rolling_columns:
            data[col+'_rolling_'+str(i)] = temp[col]

# %%
len(pd_train), len(pd_test)
# Out:
# (131342, 91486)

# %%
len(pd_train.columns), len(pd_test.columns)
# Out:
# (134, 132)

# %% [markdown]
# # 数据切分

# %%
len(list(pd_train.columns))
# Out:
# 134

# %%
len(set(pd_train.columns) & set(pd_test.columns))
# Out:
# 132

# %%
remove_columns = ['collectionName','phoneName','latDeg_truth','lngDeg_truth','phone']
features_columns = [col for col in pd_test.columns if col not in remove_columns]

# %%
X_train = pd_train[features_columns]
X_test = pd_test[features_columns]
y_latDeg = pd_train['latDeg_truth']
y_lngDeg = pd_train['lngDeg_truth']

# %%
xtr1,xval1,ytr1,yval1 = train_test_split(X_train, y_latDeg, test_size=0.3, random_state=10)
xtr2,xval2,ytr2,yval2 = train_test_split(X_train, y_lngDeg, test_size=0.3, random_state=10)

# %% [markdown]
# # 模型训练

# %%
params = {
    'objective': 'mae',
    'max_bin': 600,
    'learning_rate': 0.02,
    'num_leaves': 80
}

lgb_train = lgb.Dataset(xtr1, ytr1)
lgb_eval = lgb.Dataset(xval1, yval1, reference=lgb_train)

model_latDeg = lgb.train(
    params, lgb_train,
    valid_sets=[lgb_train, lgb_eval],
    verbose_eval=25,
    num_boost_round=10000,
    early_stopping_rounds=10
)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0
# [3150]	training's l1: 8.31101e-05	valid_1's l1: 9.36397e-05
# [3175]	training's l1: 8.2975e-05	valid_1's l1: 9.34194e-05
# [3200]	training's l1: 8.27154e-05	valid_1's l1: 9.31962e-05
# [3225]	training's l1: 8.24711e-05	valid_1's l1: 9.30219e-05
# [3250]	training's l1: 8.23705e-05	valid_1's l1: 9.2981e-05
# [3275]	training's l1: 8.20978e-05	valid_1's l1: 9.27834e-05
# [3300]	training's l1: 8.2029e-05	valid_1's l1: 9.27708e-05
# [3325]	training's l1: 8.19529e-05	valid_1's l1: 9.27465e-05
# [3350]	training's l1: 8.18444e-05	valid_1's l1: 9.27199e-05
# [3375]	training's l1: 8.17988e-05	valid_1's l1: 9.26954e-05
# [3400]	training's l1: 8.17607e-05	valid_1's l1: 9.26709e-05
# [3425]	training's l1: 8.17061e-05	valid_1's l1: 9.26409e-05
# [3450]	training's l1: 8.16405e-05	valid_1's l1: 9.25876e-05
# [3475]	training's l1: 8.12801e-05	valid_1's l1: 9.228e-05
# [3500]	training's l1: 8.11535e-05	valid_1's l1: 9.21887e-05
# [3525]	training's l1: 8.09777e-05	valid_1's l1: 9.20542e-05
# [3550]	training's l1: 8.07195e-05	valid_1's l1: 9.1836e-05
# [3575]	training's l1: 8.05595e-05	valid_1's l1: 9.17203e-05
# [3600]	training's l1: 8.05189e-05	valid_1's l1: 9.17101e-05
# [3625]	training's l1: 8.04795e-05	valid_1's l1: 9.17007e-05
# [3650]	training's l1: 8.04337e-05	valid_1's l1: 9.16832e-05
# [3675]	training's l1: 7.97002e-05	valid_1's l1: 9.10316e-05
# [3700]	training's l1: 7.95901e-05	valid_1's l1: 9.1019e-05
# [3725]	training's l1: 7.94793e-05	valid_1's l1: 9.09931e-05
# [3750]	training's l1: 7.93754e-05	valid_1's l1: 9.09493e-05
# [3775]	training's l1: 7.91427e-05	valid_1's l1: 9.07801e-05
# [3800]	training's l1: 7.90061e-05	valid_1's l1: 9.06865e-05
# [3825]	training's l1: 7.88957e-05	valid_1's l1: 9.06395e-05
# [3850]	training's l1: 7.87625e-05	valid_1's l1: 9.05749e-05
# [3875]	training's l1: 7.85455e-05	valid_1's l1: 9.04098e-05
# [3900]	training's l1: 7.8431e-05	valid_1's l1: 9.03485e-05
# [3925]	training's l1: 7.83305e-05	valid_1's l1: 9.02866e-05
# [3950]	training's l1: 7.81571e-05	valid_1's l1: 9.01654e-05
# [3975]	training's l1: 7.80536e-05	valid_1's l1: 9.01102e-05
# [4000]	training's l1: 7.7977e-05	valid_1's l1: 9.00979e-05
# Early stopping, best iteration is:
# [4010]	training's l1: 7.79399e-05	valid_1's l1: 9.00941e-05

# %%
params = {
    'objective': 'mae',
    'max_bin': 600,
    'learning_rate': 0.02,
    'num_leaves': 80
}

lgb_train = lgb.Dataset(xtr2, ytr2)
lgb_eval = lgb.Dataset(xval2, yval2, reference=lgb_train)

model_lngDeg = lgb.train(
    params, lgb_train,
    valid_sets=[lgb_train, lgb_eval],
    verbose_eval=25,
    num_boost_round=10000,
    early_stopping_rounds=10
)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0
# [2300]	training's l1: 0.00015815	valid_1's l1: 0.000167766
# [2325]	training's l1: 0.000158017	valid_1's l1: 0.00016767
# [2350]	training's l1: 0.000157691	valid_1's l1: 0.000167462
# [2375]	training's l1: 0.00015735	valid_1's l1: 0.000167242
# [2400]	training's l1: 0.00015709	valid_1's l1: 0.000167076
# [2425]	training's l1: 0.000156707	valid_1's l1: 0.000166797
# [2450]	training's l1: 0.000156475	valid_1's l1: 0.00016666
# [2475]	training's l1: 0.00015636	valid_1's l1: 0.000166614
# [2500]	training's l1: 0.000156205	valid_1's l1: 0.000166523
# [2525]	training's l1: 0.000156091	valid_1's l1: 0.000166439
# [2550]	training's l1: 0.000155822	valid_1's l1: 0.000166293
# [2575]	training's l1: 0.000155403	valid_1's l1: 0.000165916
# [2600]	training's l1: 0.00015512	valid_1's l1: 0.000165661
# [2625]	training's l1: 0.000155045	valid_1's l1: 0.000165607
# [2650]	training's l1: 0.000154987	valid_1's l1: 0.000165566
# [2675]	training's l1: 0.000154868	valid_1's l1: 0.000165489
# [2700]	training's l1: 0.000154791	valid_1's l1: 0.000165459
# [2725]	training's l1: 0.000154567	valid_1's l1: 0.000165394
# Early stopping, best iteration is:
# [2728]	training's l1: 0.000154545	valid_1's l1: 0.000165392

# %% [markdown]
# # 模型验证

# %%
y_pred = model_latDeg.predict(xval1)
y_true = np.array(yval1)
mean_absolute_error(y_true, y_pred)
# Out:
# 9.011009998305294e-05

# %%
y_pred = model_lngDeg.predict(xval1)
y_true = np.array(yval2)
mean_absolute_error(y_true, y_pred)
# Out:
# 0.0001654727777542729

# %%
# ytr2,yval2

# %% [markdown]
# # 模型预测

# %%
y_latDeg = model_latDeg.predict(X_test)

# %%
y_lngDeg = model_lngDeg.predict(X_test)

# %% [markdown]
# # 提交结果

# %%
submission = pd_test[['phone','millisSinceGpsEpoch']]
submission['latDeg'] = list(y_latDeg)
submission['lngDeg'] = list(y_lngDeg)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_sub = data_sub[['phone', 'millisSinceGpsEpoch']].merge(submission,on=['phone', 'millisSinceGpsEpoch'],how='inner')

# %%
df_sub.to_csv("./submission.csv",index=False)

# %%
# !head ./submission.csv
# Out:
# phone,millisSinceGpsEpoch,latDeg,lngDeg
# 2020-05-15-US-MTV-1_Pixel4,1273608785432,37.41653180109113,-122.08180662657895
# 2020-05-15-US-MTV-1_Pixel4,1273608786432,37.41641363496,-122.08189289766551
# 2020-05-15-US-MTV-1_Pixel4,1273608787432,37.41656116216651,-122.08202282966545
# 2020-05-15-US-MTV-1_Pixel4,1273608788432,37.41657264197658,-122.08202296028668
# 2020-05-15-US-MTV-1_Pixel4,1273608789432,37.416580059782554,-122.0820016316261
# 2020-05-15-US-MTV-1_Pixel4,1273608790432,37.416564160973884,-122.08200707242443
# 2020-05-15-US-MTV-1_Pixel4,1273608791432,37.41657714101826,-122.08201973326467
# 2020-05-15-US-MTV-1_Pixel4,1273608792432,37.41657986248146,-122.08201975181262
# 2020-05-15-US-MTV-1_Pixel4,1273608793432,37.41658057149589,-122.08202448103182
